# %%
import pandas as pd
import json
import matplotlib.pyplot as plt
import difflib


with open("../json/pl_alt.json", "r", encoding="utf-8") as f:
    pl = json.load(f)

with open("../json/hello_worlds_v4.json", "r", encoding="utf-8") as f:
    hellos = json.load(f)


hellos_names = list(map(lambda x: x["language"].lower(), hellos))
pl_names = list(map(lambda x: x["name"].lower(), pl))


match = list(filter(lambda x: x not in hellos_names, pl_names))

m = hellos_names + pl_names
x = list(set(m))
print(x)
# Out:
# ['janus-programming-language', 'pl-s', 'm4sugar', 'plush', 'camal', 's-snobol', 'metalang99', 'jruby', 'plankalkül', 'orc-lang', 'luna', 'hummingbird-quickscript', 'scallop', 'blade-lang', 'luau', 'dylan', 'intuitionistic', 'pm2', 'lrltran', 'mlisp2', 'rlox', 'elixir', 'cadence-skill', 'ghostscript', 'mascara', 'dbase', 'tomal', 'woofjs', 'forsp', 'pin', 'fern', 'service-modeling-language', 'vbscript', 'modula-3', 'sisc', 'dwim', 'aui-lang', 'scala.js', 'kl0', 'extensible-embeddable-language', 'flownote', 'writeacourse', 'eclectic-csp', 'harbour', 'kek-nodal', 'flaming\xa0thunder', 'ibm-basic', 'z-flat', 'blue', 'alphabasic', 'ease', 'mads', 'ppl', 'sql\xa0(oracle)', 'flix', 'mathics', 'mlatu', 'search', 'datalog', 'ampl', 'kamby', 'egl', 'sqlpl', 'data-text', 'flic', 'pascal-mtp', 'rpl-lang', 'damn', 'dm', 'eve', 'omnitab-ii', 'expresso', 'maple', 'pike', 'afnix', 'lisp-machine-lisp', 'olga', 'ops5', 'aith', 'tinkertoy', 'paragon', 'amalthea', 'genero\xa0bdl', 'fortran-iv', 'p', 'di
# ...
